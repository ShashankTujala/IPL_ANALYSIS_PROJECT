# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import sys
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)
import importlib
import src.analysis
print(os.getcwd())
importlib.reload(src.analysis)
sys.path.append(os.path.abspath(".."))
print(os.listdir(os.path.abspath("..")))
# Out:
# c:\Users\shash\OneDrive\IPL Analysis Project\notebooks
# ['datasets', 'notebooks', 'README.md', 'requirements.txt', 'src']

# %%
data = src.analysis.batsman_data()

bowl = src.analysis.bowler_data()

# %%
from src.analysis import Top_Scorers
Top_Scorers(data)

# %%
from src.analysis import Most_4s
Most_4s(data)

# %%
from src.analysis import Most_sr
Most_sr(data)

# %%
from src.analysis import Most_6s
Most_6s(data)

# %%
from src.analysis import Best_avg
Best_avg(data)

# %%
from src.analysis import Most_wkts
Most_wkts(bowl)

# %%
from src.analysis import Best_bowl_avg
Best_bowl_avg(bowl)

# %%
from src.analysis import Best_Econ
Best_Econ(bowl)

# %%
from src.analysis import Most_4wkts
Most_4wkts(bowl)

# %%
from src.analysis import Most_5wkts
Most_5wkts(bowl)

# %%
from src.analysis import Best_bowl_sr
Best_bowl_sr(bowl)

# %%
from src.analysis import sr_vs_avg
sr_vs_avg(bowl)

# %%
from src.analysis import corrheatmap
corrheatmap(bowl)
